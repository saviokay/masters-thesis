# %%
import dask
import numpy as np
import xarray as xr
import glob
import matplotlib.pyplot as plt
import time
import datetime
from dask_jobqueue import SLURMCluster
from dask.distributed import Client
import warnings

# %%
warnings.filterwarnings('ignore')
now = datetime.datetime.now()
now_string = str(now.strftime("%Y-%m-%d_%A_%H%M%S"))
now_string
# Out:
# '2019-07-05_Friday_232927'

# %%
cluster = SLURMCluster(cores=16, memory='20GB', project='pi_jianwu', walltime='02:00:00', queue='high_mem', job_extra=['--qos=medium+','--exclusive'])

# %%
cluster.scale(5)

# %%
# !squeue -u savio1
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            1074936  high_mem dask-wor   savio1 CG       6:47      1 cnode031
#            1074937  high_mem dask-wor   savio1 CG       6:47      1 cnode006
#            1074938  high_mem dask-wor   savio1 CG       6:47      1 cnode007
#            1074939  high_mem dask-wor   savio1 CG       6:47      1 cnode025
#            1074940  high_mem dask-wor   savio1 CG       6:47      1 cnode026
#            1074947  high_mem dask-wor   savio1 PD       0:00      1 (None)
#            1074948  high_mem dask-wor   savio1 PD       0:00      1 (None)
#            1074949  high_mem dask-wor   savio1 PD       0:00      1 (None)
#            1074922  high_mem   tunnel   savio1  R      54:13     16 cnode[009-024]

# %%
client = Client()

# %%
cluster.dashboard_link
# Out:
# 'http://10.2.1.9:37725/status'

# %%
cluster.running_jobs
# Out:
# OrderedDict()

# %%
cluster.pending_jobs
# Out:
# OrderedDict([('1074947', {}),
#              ('1074948', {}),
#              ('1074949', {}),
#              ('1074950', {}),
#              ('1074951', {})])

# %%
t0 = time.time()
total_pix = np.zeros((180, 360))
cloud_pix = np.zeros((180, 360))

# %%
def ingest_data(M03_dir, M06_dir):
    M03_files = sorted(glob.glob(M03_dir + "MYD03.A2008*.hdf"))
    M06_files = sorted(glob.glob(M06_dir + "MYD06_L2.A2008*.hdf"))
    for M03, M06 in zip (M03_files, M06_files):
        d06 = xr.open_mfdataset(M06[:], parallel=True)['Cloud_Mask_1km'][:,:,:].values
        d06CM = d06[::3,::3,0]
        ds06_decoded = (np.array(d06CM, dtype = "byte") & 0b00000110) >> 1
        d03_lat = xr.open_mfdataset(M03[:], drop_variables = "Scan Type", parallel=True)['Latitude'][:,:].values
        d03_lon = xr.open_mfdataset(M03[:], drop_variables = "Scan Type", parallel=True)['Longitude'][:,:].values

        lat = d03_lat[::3,::3]
        lon = d03_lon[::3,::3]

        l_index = (lat + 89.5).astype(int).reshape(lat.shape[0]*lat.shape[1])
        lat_index = np.where(l_index > -1, l_index, 0)
        ll_index = (lon + 179.5).astype(int).reshape(lon.shape[0]*lon.shape[1])
        lon_index = np.where(ll_index > -1, ll_index, 0)
        for i, j in zip(lat_index, lon_index):
            total_pix[i,j] += 1

        indicies = np.nonzero(ds06_decoded <= 0)
        row_i = indicies[0]
        column_i = indicies[1]
        cloud_lon = [lon_index.reshape(ds06_decoded.shape[0],ds06_decoded.shape[1])[i,j] for i, j in zip(row_i, column_i)]
        cloud_lat = [lat_index.reshape(ds06_decoded.shape[0],ds06_decoded.shape[1])[i,j] for i, j in zip(row_i, column_i)]

        for x, y in zip(cloud_lat, cloud_lon):
            cloud_pix[int(x),int(y)] += 1
            
    return cloud_pix, total_pix

# %%
t0 = time.time()
import dask.multiprocessing
dask.config.set(num_workers=5)
M03_dir = "/home/savio1/cybertrn_common/Data/Satellite_Observations/MODIS/MYD03/"
M06_dir = "/home/savio1/cybertrn_common/Data/Satellite_Observations/MODIS/MYD06_L2/"
future1 = client.submit(ingest_data,M03_dir,M06_dir)
result1 = client.gather(future1)

# %%
future1.result()
# Out:
# (array([[2.61658e+05, 1.33400e+03, 1.22700e+03, ..., 1.22500e+03,
#          1.22700e+03, 5.96000e+02],
#         [3.50400e+03, 2.25900e+03, 2.30500e+03, ..., 2.32600e+03,
#          2.13200e+03, 1.14300e+03],
#         [4.93500e+03, 3.27700e+03, 3.43500e+03, ..., 3.27300e+03,
#          3.14900e+03, 1.68100e+03],
#         ...,
#         [3.32100e+03, 2.15500e+03, 2.16200e+03, ..., 2.15200e+03,
#          2.22700e+03, 1.03900e+03],
#         [1.46100e+03, 9.85000e+02, 9.38000e+02, ..., 9.39000e+02,
#          9.89000e+02, 4.65000e+02],
#         [1.57000e+02, 1.06000e+02, 1.13000e+02, ..., 1.13000e+02,
#          9.00000e+01, 4.50000e+01]]),
#  array([[2.65859e+05, 4.05500e+03, 3.99700e+03, ..., 4.03600e+03,
#          4.02900e+03, 1.95000e+03],
#         [1.10130e+04, 7.32400e+03, 7.34400e+03, ..., 7.32900e+03,
#          7.29500e+03, 3.63800e+03],
#         [1.59950e+04, 1.04680e+04, 1.09660e+04, ..., 1.07490e+04,
#          1.04050e+04, 5.51000e+03],
#         ...,
#         [1.08460e+04, 7.31500e+03, 7.15000e+03, ..., 7.20000e+03,
#          7.37300e+03, 3.57400e+03],
#         [5.26200e+03, 3.59600e+03, 3.49800e+03, ..., 3.57600e+03,
#          3.55000e+03, 1.75000e+03],
#         [6.46000e+02, 4.45000e+02, 4.48000e+02, ..., 4.73000e+02,
#          4.29000e+02, 2.14000e+02]]))

# %%
cf1 = future1.result()[0]/future1.result()[1]

# %%
plt.figure(figsize=(14,7))
plt.contourf(range(-180,180), range(-90,90), cf1, 100, cmap = "jet")
plt.xlabel("Longitude", fontsize = 14)
plt.ylabel("Latitude", fontsize = 14)
plt.title("Level 3 Cloud Fraction Aggregation For One Month %s" %now_string, fontsize = 16)
plt.colorbar()
plt.savefig("/umbc/xfs1/jianwu/common/MODIS_Aggregation/savioexe/test/8/%s.png" %now_string)

# %%
cf2 = xr.DataArray(cf1)
cf2.to_netcdf("/umbc/xfs1/jianwu/common/MODIS_Aggregation/savioexe/test/8/%s.hdf" %now_string)

# %%
t1 = time.time()
total = t1-t0
print(total)
# Out:
# 12426.781093597412

# %%
print(total/3600,"hours")
# Out:
# 3.451883637110392 hours

# %%
cluster.pending_jobs
# Out:
# OrderedDict()

# %%
cluster.close()

# %%
client.close()
# Out:
# distributed.scheduler - INFO - Clear task state
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:33966'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:42953'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:37786'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:34799'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:42838'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:42024'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:38976'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:45865'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:44668'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:35492'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:45577'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:36923'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:35438'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:34125'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:39613'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:45498'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:32772'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:35344'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:34560'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:36969'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:36003'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:35252'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:35698'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:40158'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:40096'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:46438'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:34820'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:44452'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:46417'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:42981'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:40241'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:45084'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:37000'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:44066'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:41450'
# distributed.nanny - INFO - Closing Nanny at 'tcp://127.0.0.1:42632'
# distributed.scheduler - INFO - Remove worker tcp://127.0.0.1:40771
# distributed.core - INFO - Removing comms to tcp://127.0.0.1:40771
# distributed.scheduler - INFO - Remove worker tcp://127.0.0.1:45365
# distributed.core - INFO - Removing comms to tcp://127.0.0.1:45365
# distributed.scheduler - INFO - Remove worker tcp://127.0.0.1:35281
# distributed.core - INFO - Removing comms to tcp://127.0.0.1:35281
# distributed.scheduler - INFO - Scheduler closing...
# distributed.scheduler - INFO - Scheduler closing all comms

# %%
# !squeue -u savio1
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            1074922  high_mem   tunnel   savio1  R    4:21:22     16 cnode[009-024]
