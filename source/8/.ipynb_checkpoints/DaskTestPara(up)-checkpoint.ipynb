# %%
import dask
import numpy as np
import xarray as xr
import glob
import matplotlib.pyplot as plt
import time
#from dask_jobqueue import SLURMCluster
from dask.distributed import Client

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:54363")
client
# Out:
# <Client: scheduler='tcp://127.0.0.1:54363' processes=5 cores=5>

# %%
#cluster = SLURMCluster(cores=16, memory='20GB', project='pi_jianwu', walltime='02:00:00', queue='high_mem', job_extra=['--qos=medium+'])

# %%
#cluster.scale(5)

# %%
#client = Client()

# %%
client
# Out:
# <Client: scheduler='tcp://127.0.0.1:54363' processes=5 cores=5>

# %%
t0 = time.time()

#M03_dir = "/home/savio1/cybertrn_common/Data/Satellite_Observations/MODIS/MYD03/"
M03_dir = "/Users/saviosebastian/Documents/Project/CMAC/HDFFiles3/"
#M06_dir = "/home/savio1/cybertrn_common/Data/Satellite_Observations/MODIS/MYD06_L2/"
M06_dir = "/Users/saviosebastian/Documents/Project/CMAC/HDFFiles3/"
#M03_files = sorted(glob.glob(M03_dir + "MYD03.A2008*.hdf"))
#M06_files = sorted(glob.glob(M06_dir + "MYD06_L2.A2008*.hdf"))
total_pix = np.zeros((180, 360))
cloud_pix = np.zeros((180, 360))

# %%
def ingest_data(M03_dir, M06_dir):
    M03_files = sorted(glob.glob(M03_dir + "MYD03.A2008*.hdf"))
    M06_files = sorted(glob.glob(M06_dir + "MYD06_L2.A2008*.hdf"))
    for M03, M06 in zip (M03_files, M06_files):
        d06 = xr.open_mfdataset(M06[:], parallel=True)['Cloud_Mask_1km'][:,:,:].values
        d06CM = d06[::3,::3,0]
        ds06_decoded = (np.array(d06CM, dtype = "byte") & 0b00000110) >> 1
        d03_lat = xr.open_mfdataset(M03[:], drop_variables = "Scan Type", parallel=True)['Latitude'][:,:].values
        d03_lon = xr.open_mfdataset(M03[:], drop_variables = "Scan Type", parallel=True)['Longitude'][:,:].values

        lat = d03_lat[::3,::3]
        lon = d03_lon[::3,::3]

        l_index = (lat + 89.5).astype(int).reshape(lat.shape[0]*lat.shape[1])
        lat_index = np.where(l_index > -1, l_index, 0)
        ll_index = (lon + 179.5).astype(int).reshape(lon.shape[0]*lon.shape[1])
        lon_index = np.where(ll_index > -1, ll_index, 0)
        for i, j in zip(lat_index, lon_index):
            total_pix[i,j] += 1

        indicies = np.nonzero(ds06_decoded <= 0)
        row_i = indicies[0]
        column_i = indicies[1]
        cloud_lon = [lon_index.reshape(ds06_decoded.shape[0],ds06_decoded.shape[1])[i,j] for i, j in zip(row_i, column_i)]
        cloud_lat = [lat_index.reshape(ds06_decoded.shape[0],ds06_decoded.shape[1])[i,j] for i, j in zip(row_i, column_i)]

        for x, y in zip(cloud_lat, cloud_lon):
            cloud_pix[int(x),int(y)] += 1
            
    return cloud_pix, total_pix

# %%
# %time
import dask.multiprocessing
dask.config.set(num_workers=5)
M03_dir = "/Users/saviosebastian/Documents/Project/CMAC/HDFFiles3/"
M06_dir = "/Users/saviosebastian/Documents/Project/CMAC/HDFFiles3/"
future1 = client.submit(ingest_data,M03_dir,M06_dir)
result1 = client.gather(future1)

# %%
future1.result()
# Out:
# (array([[6840.,  416.,  516., ...,  456.,  416.,  204.],
#         [ 844.,  504.,  576., ...,  500.,  508.,  288.],
#         [ 436.,  216.,  272., ...,  236.,  224.,  164.],
#         ...,
#         [ 836.,  520.,  540., ...,  492.,  504.,  216.],
#         [ 648.,  384.,  424., ...,  396.,  372.,  220.],
#         [  68.,   88.,   76., ...,   48.,   36.,   12.]]),
#  array([[7028.,  500.,  616., ...,  552.,  536.,  260.],
#         [1464.,  924., 1036., ...,  980.,  944.,  496.],
#         [2132., 1388., 1420., ..., 1388., 1400.,  720.],
#         ...,
#         [1440.,  880.,  900., ...,  892.,  868.,  384.],
#         [ 756.,  384.,  440., ...,  424.,  380.,  224.],
#         [  68.,   92.,   76., ...,   48.,   36.,   12.]]))

# %%
cf1 = future1.result()[0]/future1.result()[1]
# Out:
# /Users/saviosebastian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /Users/saviosebastian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(14,7))
plt.contourf(range(-180,180), range(-90,90), cf1, 100, cmap = "jet")
plt.xlabel("Longitude", fontsize = 14)
plt.ylabel("Latitude", fontsize = 14)
plt.title("Level 3 Cloud Fraction Aggregation For One Month With A Subsampling Of 3 And Parallelism [::3,::3]", fontsize = 16)
plt.colorbar()
plt.savefig("/Users/saviosebastian/Documents/Project/CMAC/HDFFiles/test123.png")

# %%
cf2 = xr.DataArray(cf1)
cf2.to_netcdf("/Users/saviosebastian/Documents/Project/CMAC/HDFFiles/test123.hdf")

# %%
cf = cloud_pix/total_pix
cf
# Out:
# /Users/saviosebastian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /Users/saviosebastian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
plt.figure(figsize=(14,7))
plt.contourf(range(-180,180), range(-90,90), cf, 100, cmap = "jet")
plt.xlabel("Longitude", fontsize = 14)
plt.ylabel("Latitude", fontsize = 14)
plt.title("Level 3 Cloud Fraction Aggregation For One Month With A Subsampling Of 3 And Parallelism [::3,::3]", fontsize = 16)
plt.colorbar()
plt.savefig("/Users/saviosebastian/Documents/Project/CMAC/HDFFiles/test123.png")
# Out:
# /Users/saviosebastian/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1557: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# /Users/saviosebastian/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1558: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# /Users/saviosebastian/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1203: RuntimeWarning: invalid value encountered in less
#   under = np.nonzero(lev < self.zmin)[0]
# /Users/saviosebastian/anaconda3/lib/python3.7/site-packages/matplotlib/contour.py:1205: RuntimeWarning: invalid value encountered in greater
#   over = np.nonzero(lev > self.zmax)[0]

# %%
cf = cloud_pix/total_pix
plt.figure(figsize=(14,7))
plt.contourf(range(-180,180), range(-90,90), cf, 100, cmap = "jet")
plt.xlabel("Longitude", fontsize = 14)
plt.ylabel("Latitude", fontsize = 14)
plt.title("Level 3 Cloud Fraction Aggregation For One Month With A Subsampling Of 3 And Parallelism [::3,::3]", fontsize = 16)
plt.colorbar()
plt.savefig("/home/jovyan/testpara_onemonth.png")
cf1 = xr.DataArray(cf)
cf1.to_netcdf("/home/jovyan/testpara_onemonth.hdf")
t1 = time.time()
total = t1-t0
print(total)
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# 52.201626777648926

# %%
cluster.close()

# %%
client.close()
# Out:
# tornado.application - ERROR - Exception in Future <Future cancelled> after timeout
# Traceback (most recent call last):
#   File "/umbc/xfs1/jianwu/common/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 970, in error_callback
#     future.result()
# concurrent.futures._base.CancelledError

# %%
cluster.close()
